# %% [markdown]
# <a href="https://colab.research.google.com/github/Vonewman/Deep_Learning_models_with_pytorch/blob/master/Basics_Linear_Regression_with_Pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable

# %%
x_data = Variable(torch.Tensor([[1.0], [2.0], [3.0]])) 
y_data = Variable(torch.Tensor([[2.0], [4.0], [6.0]]))

# %%
class LinearRegressionModel(nn.Module):

    def __init__(self):
        super(LinearRegressionModel, self).__init__()
        self.linear = torch.nn.Linear(1, 1)  # One in and one out

    def forward(self, x):
        y_pred = self.linear(x)
        return y_pred

# %%
our_model = LinearRegressionModel()

# %%
criterion = nn.MSELoss(size_average=False)
optimizer = torch.optim.SGD(our_model.parameters(), lr = 0.01)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))

# %%
## training step
for epoch in range(500):

    # Forward pass: Compute predicted y by passing  
    # x to the model 
    pred_y = our_model(x_data) 
  
    # Compute and print loss 
    loss = criterion(pred_y, y_data) 
  
    # Zero gradients, perform a backward pass,  
    # and update the weights. 
    optimizer.zero_grad() 
    loss.backward() 
    optimizer.step() 
    print('epoch {}, loss {}'.format(epoch, loss.item()))
# Out:
# epoch 0, loss 57.73883056640625
# epoch 1, loss 25.710086822509766
# epoch 2, loss 11.451711654663086
# epoch 3, loss 5.104195594787598
# epoch 4, loss 2.2783727645874023
# epoch 5, loss 1.020308017730713
# epoch 6, loss 0.46016690135002136
# epoch 7, loss 0.21072176098823547
# epoch 8, loss 0.09959165751934052
# epoch 9, loss 0.05003659054636955
# epoch 10, loss 0.027894260361790657
# epoch 11, loss 0.01795642450451851
# epoch 12, loss 0.013452700339257717
# epoch 13, loss 0.011369405314326286
# epoch 14, loss 0.010364641435444355
# epoch 15, loss 0.009841115213930607
# epoch 16, loss 0.009532959200441837
# epoch 17, loss 0.009321698918938637
# epoch 18, loss 0.009154661558568478
# epoch 19, loss 0.009008380584418774
# epoch 20, loss 0.008872410282492638
# epoch 21, loss 0.008741913363337517
# epoch 22, loss 0.008614998310804367
# epoch 23, loss 0.008490612730383873
# epoch 24, loss 0.008368359878659248
# epoch 25, loss 0.008247971534729004
# epoch 26, loss 0.00812939740717411
# ...

# %%
new_var = Variable(torch.Tensor([[4.0]])) 
pred_y = our_model(new_var) 
print("predict (after training)", 4, our_model(new_var).item())
# Out:
# predict (after training) 4 8.003378868103027
